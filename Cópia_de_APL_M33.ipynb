# %% [markdown]
# <a href="https://colab.research.google.com/github/rkivejuqis/INTED2025M/blob/main/C%C3%B3pia_de_APL_M33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 50
b = 15
print (a+b)
# Out:
# 65

# %% [markdown]
# #Algoritimo Lógica de Programação
# ## Introdução

# %% [markdown]
# ## Tipos de dados
# int - inteiros - para numeros interios
#
# float - flutuantes - para numeros com vírgulas
#
# str - string - para palavras e textos
#
# bool - booleano - para binários - True ou False

# %%
x= int (input("Digite um número:"))
y= float(input("Digite um numero com vírgula:"))
z= str(input("digite uma palavra:"))
w=bool(input("digite um Binário:"))
# Out:
# Digite um número:16
# Digite um numero com vírgula:1.6
# digite uma palavra:Stich
# digite um Binário:True

# %%
print(x)
print(y)
print(w)
print(z)
# Out:
# 16
# 1.6
# True
# Stich

# %%
print("este é um número inteiro: ", x , "outro texto")
# Out:
# este é um número inteiro:  16 outro texto

# %% [markdown]
# 1 - crie um algoritmo que receba em variavel um nome, e em outra uma idade. (nome, idade) depois mostre na tela a seguinte frase:
#
# Eu sou **nome** e tenho **idade** anos!

# %%
nome = str(input("Digite seu nome"))
idade = int( input("Digite sua idade"))
print("Eu sou", nome , "e tenho", idade, "anos !")
# Out:
# Digite seu nome Stich
# Digite sua idade 16
# Eu sou  Stich e tenho 16 anos !

# %% [markdown]
# ## Operadores
# Adição +
#
# Subtração -
#
# Multiplicação *
#
# Divisão /
#
# Resto da divisão %
#
# Exponeciação **

# %% [markdown]
# 2 - crie um algoritmo que leia 2 números e imprima na tela o resultado das operações acima.

# %%
#Entrada
numero1 = int(input("Digite o primeiro número: "))
numero2 = int(input("Digite o segundo número: "))

#Processamento
soma = numero1 + numero2
subtracao = numero1 - numero2
multiplicacao = numero1 * numero2
divisao = numero1 / numero2
resto = numero1 % numero2
exponenciacao = numero1 ** numero2

#Saída
print("Soma:", soma)
print("Subtração:", subtracao)
print("Multiplicação:", multiplicacao)
print("Divisão:", divisao)
print("Resto da divisão:", resto)
print(f"Exponenciação: {exponenciacao:.2e}")
# Out:
# Digite o primeiro número: 23
# Digite o segundo número: 16
# Soma: 39
# Subtração: 7
# Multiplicação: 368
# Divisão: 1.4375
# Resto da divisão: 7
# Exponenciação: 6.13e+21

# %% [markdown]
# 3 - Crie um algoritimo, que receba o nome do usuário, e 3 notas, depois calcule a média na variável (media), e imprima na tela a seguinte frase:
#
# O aluno (nome) está com (media) de média!

# %%
# Entrada
nome = input("Digite o nome do aluno: ")
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))

# Processamento
media = (nota1 + nota2 + nota3) / 3

# Saída
print(f"O aluno {nome} está com {media:.2f} de média!")
# Out:
# Digite o nome do aluno: stich
# Digite a primeira nota: 7
# Digite a segunda nota: 10
# Digite a terceira nota: 10
# O aluno stich está com 9.00 de média!
